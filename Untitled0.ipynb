# %% [markdown]
# <a href="https://colab.research.google.com/github/Jastipriyavarsha/-SOFTWARE-ENGINEERING/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#addition of numbers
a = 4
print(a)
a = 4
b = 4
print(a+b)
# Out:
# 4
# 8
